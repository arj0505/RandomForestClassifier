# %%
import pandas as pd

# %%
df=pd.read_table(r"C:\Users\arjun\Desktop\Logs\Network-Log-and-Traffic-Analysis-master\conn_sample.log",header=None,names=['ts','uid','id.orig_h','id.orig_p','id.resp_h','id.resp_p','proto','service','duration','orig_bytes','resp_bytes','conn_state','local_orig','missed_bytes','history','orig_pkts','orig_ip_bytes','resp_pkts','resp_ip_bytes','tunnel_parents','threat','sample'])

# %%
df.head()
# Out:
#              ts                 uid        id.orig_h  id.orig_p  \
# 0  1.331901e+09  C6SwUo2lWDfrpgfgVl   192.168.202.79      50504
# 1  1.331901e+09  C26Bhi2scZzizn7ph9   192.168.202.79      50681
# 2  1.331901e+09   CnbU9V2P0WWwMlO1l   192.168.202.76      51719
# 3  1.331901e+09   Cyu9CADFj5Kg5rhf4   192.168.202.79      48479
# 4  1.331901e+09   CcUhD5kLSPzplLI5e  192.168.202.100      45658
#
#          id.resp_h  id.resp_p proto service  duration orig_bytes  ...  \
# 0  192.168.229.251         80   tcp    http  0.010000        182  ...
# 1  192.168.229.251         80   tcp    http  0.010000        172  ...
# 2  213.199.179.147         80   tcp       -  3.010000          0  ...
# 3  192.168.229.153      49160   tcp       -  0.010000        198  ...
# 4   192.168.27.152      17533   udp       -         -          -  ...
#
#   local_orig missed_bytes   history  orig_pkts orig_ip_bytes  resp_pkts  \
# 0          -            0   ShADfFa          4           398          3
# ...

# %%
df.shape
# Out:
# (22694, 22)

# %%
#k=df.to_csv(r"C:\Users\arjun\Desktop\Logs\Network-Log-and-Traffic-Analysis-master\conn_sample.csv")

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\arjun\Desktop\Logs\Network-Log-and-Traffic-Analysis-master\conn_sample.csv")
df.head()
# Out:
#            ts                 uid        id.orig_h  id.orig_p  \
# 0  1331901000  C6SwUo2lWDfrpgfgVl   192.168.202.79      50504
# 1  1331901001  C26Bhi2scZzizn7ph9   192.168.202.79      50681
# 2  1331901050   CnbU9V2P0WWwMlO1l   192.168.202.76      51719
# 3  1331901080   Cyu9CADFj5Kg5rhf4   192.168.202.79      48479
# 4  1331901028   CcUhD5kLSPzplLI5e  192.168.202.100      45658
#
#          id.resp_h  id.resp_p proto service duration orig_bytes  ...  \
# 0  192.168.229.251         80   tcp    http     0.01        182  ...
# 1  192.168.229.251         80   tcp    http     0.01        172  ...
# 2  213.199.179.147         80   tcp       -     3.01          0  ...
# 3  192.168.229.153      49160   tcp       -     0.01        198  ...
# 4   192.168.27.152      17533   udp       -        -          -  ...
#
#   local_orig missed_bytes   history  orig_pkts orig_ip_bytes  resp_pkts  \
# 0          -            0   ShADfFa          4           398          3
# ...

# %% [markdown]
# ###### Data Summary

# %%
df.describe()
# Out:
#                  ts     id.orig_p     id.resp_p  missed_bytes      orig_pkts  \
# count  2.269400e+04  22694.000000  22694.000000       22694.0   22694.000000
# mean   1.331949e+09  42753.924077  20598.650612           0.0      11.734511
# std    4.277651e+04  15289.541275  20788.309643           0.0    1563.859576
# min    1.331901e+09      3.000000      0.000000           0.0       0.000000
# 25%    1.331908e+09  36057.750000   2133.000000           0.0       1.000000
# 50%    1.331928e+09  44316.000000  10379.000000           0.0       1.000000
# 75%    1.331997e+09  54534.500000  38230.500000           0.0       1.000000
# max    1.332018e+09  65491.000000  65535.000000           0.0  235588.000000
#
#        orig_ip_bytes      resp_pkts  resp_ip_bytes  threat  sample
# count   2.269400e+04   22694.000000   2.269400e+04     0.0     0.0
# mean    1.626597e+03      11.166476   1.865159e+03     NaN     NaN
# std     2.276985e+05    1558.312166   2.548142e+05     NaN     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22694 entries, 0 to 22693
# Data columns (total 22 columns):
# ts                22694 non-null int64
# uid               22694 non-null object
# id.orig_h         22694 non-null object
# id.orig_p         22694 non-null int64
# id.resp_h         22694 non-null object
# id.resp_p         22694 non-null int64
# proto             22694 non-null object
# service           22694 non-null object
# duration          22694 non-null object
# orig_bytes        22694 non-null object
# resp_bytes        22694 non-null object
# conn_state        22694 non-null object
# local_orig        22694 non-null object
# missed_bytes      22694 non-null int64
# history           22694 non-null object
# orig_pkts         22694 non-null int64
# orig_ip_bytes     22694 non-null int64
# resp_pkts         22694 non-null int64
# resp_ip_bytes     22694 non-null int64
# tunnel_parents    22694 non-null object
# threat            0 non-null float64
# ...

# %% [markdown]
# ##### Data Types

# %% [markdown]
# Checking for the type of information Python stored in each column.

# %%
df.dtypes
# Out:
# ts                  int64
# uid                object
# id.orig_h          object
# id.orig_p           int64
# id.resp_h          object
# id.resp_p           int64
# proto              object
# service            object
# duration           object
# orig_bytes         object
# resp_bytes         object
# conn_state         object
# local_orig         object
# missed_bytes        int64
# history            object
# orig_pkts           int64
# orig_ip_bytes       int64
# resp_pkts           int64
# resp_ip_bytes       int64
# tunnel_parents     object
# threat            float64
# sample            float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# ts                    0
# uid                   0
# id.orig_h             0
# id.orig_p             0
# id.resp_h             0
# id.resp_p             0
# proto                 0
# service               0
# duration              0
# orig_bytes            0
# resp_bytes            0
# conn_state            0
# local_orig            0
# missed_bytes          0
# history               0
# orig_pkts             0
# orig_ip_bytes         0
# resp_pkts             0
# resp_ip_bytes         0
# tunnel_parents        0
# threat            22694
# sample            22694
# dtype: int64

# %%
df=df.drop(['threat','sample','tunnel_parents'],axis=1)

# %%
df.isnull().sum()
# Out:
# ts               0
# uid              0
# id.orig_h        0
# id.orig_p        0
# id.resp_h        0
# id.resp_p        0
# proto            0
# service          0
# duration         0
# orig_bytes       0
# resp_bytes       0
# conn_state       0
# local_orig       0
# missed_bytes     0
# history          0
# orig_pkts        0
# orig_ip_bytes    0
# resp_pkts        0
# resp_ip_bytes    0
# dtype: int64

# %% [markdown]
# #### Converting Feature Types

# %% [markdown]
# We're chaninging the ts (time stamp) feature to a datetime object using the function to_datetime().

# %%
from datetime import datetime
df['ts'] = [datetime.fromtimestamp(float(date)) for date in df['ts'].values]

# %%
df['ts'].head()
# Out:
# 0   2012-03-16 18:00:00
# 1   2012-03-16 18:00:01
# 2   2012-03-16 18:00:50
# 3   2012-03-16 18:01:20
# 4   2012-03-16 18:00:28
# Name: ts, dtype: datetime64[ns]

# %% [markdown]
# ##### find categorical columns

# %%
catgorical_objects=df.select_dtypes(include='object')
print(catgorical_objects.shape)
catgorical_objects.head()
# Out:
# (22694, 11)
#                   uid        id.orig_h        id.resp_h proto service  \
# 0  C6SwUo2lWDfrpgfgVl   192.168.202.79  192.168.229.251   tcp    http
# 1  C26Bhi2scZzizn7ph9   192.168.202.79  192.168.229.251   tcp    http
# 2   CnbU9V2P0WWwMlO1l   192.168.202.76  213.199.179.147   tcp       -
# 3   Cyu9CADFj5Kg5rhf4   192.168.202.79  192.168.229.153   tcp       -
# 4   CcUhD5kLSPzplLI5e  192.168.202.100   192.168.27.152   udp       -
#
#   duration orig_bytes resp_bytes conn_state local_orig   history
# 0     0.01        182        214         SF          -   ShADfFa
# 1     0.01        172        281         SF          -  ShADdfFa
# 2     3.01          0          0         S0          -         S
# 3     0.01        198        118         SF          -  ShADdfFa
# 4        -          -          -         S0          -         D

# %%
catgorical_objects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22694 entries, 0 to 22693
# Data columns (total 11 columns):
# uid           22694 non-null object
# id.orig_h     22694 non-null object
# id.resp_h     22694 non-null object
# proto         22694 non-null object
# service       22694 non-null object
# duration      22694 non-null object
# orig_bytes    22694 non-null object
# resp_bytes    22694 non-null object
# conn_state    22694 non-null object
# local_orig    22694 non-null object
# history       22694 non-null object
# dtypes: object(11)
# memory usage: 1.9+ MB

# %%
catgorical_objects.columns
# Out:
# Index(['uid', 'id.orig_h', 'id.resp_h', 'proto', 'service', 'duration',
#        'orig_bytes', 'resp_bytes', 'conn_state', 'local_orig', 'history'],
#       dtype='object')

# %%
catgorical_objects.head()
# Out:
#                   uid        id.orig_h        id.resp_h proto service  \
# 0  C6SwUo2lWDfrpgfgVl   192.168.202.79  192.168.229.251   tcp    http
# 1  C26Bhi2scZzizn7ph9   192.168.202.79  192.168.229.251   tcp    http
# 2   CnbU9V2P0WWwMlO1l   192.168.202.76  213.199.179.147   tcp       -
# 3   Cyu9CADFj5Kg5rhf4   192.168.202.79  192.168.229.153   tcp       -
# 4   CcUhD5kLSPzplLI5e  192.168.202.100   192.168.27.152   udp       -
#
#   duration orig_bytes resp_bytes conn_state local_orig   history
# 0     0.01        182        214         SF          -   ShADfFa
# 1     0.01        172        281         SF          -  ShADdfFa
# 2     3.01          0          0         S0          -         S
# 3     0.01        198        118         SF          -  ShADdfFa
# 4        -          -          -         S0          -         D

# %% [markdown]
# ##### Change categorical to numerical values

# %%
df['duration'] = pd.to_numeric(df['duration'],errors='coerce')
df['orig_bytes'] = pd.to_numeric(df['orig_bytes'],errors='coerce')
df['resp_bytes'] = pd.to_numeric(df['resp_bytes'],errors='coerce')

# %%
df['duration'].tail()
# Out:
# 22689   NaN
# 22690   NaN
# 22691   NaN
# 22692   NaN
# 22693   NaN
# Name: duration, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22694 entries, 0 to 22693
# Data columns (total 19 columns):
# ts               22694 non-null datetime64[ns]
# uid              22694 non-null object
# id.orig_h        22694 non-null object
# id.orig_p        22694 non-null int64
# id.resp_h        22694 non-null object
# id.resp_p        22694 non-null int64
# proto            22694 non-null object
# service          22694 non-null object
# duration         3870 non-null float64
# orig_bytes       3870 non-null float64
# resp_bytes       3870 non-null float64
# conn_state       22694 non-null object
# local_orig       22694 non-null object
# missed_bytes     22694 non-null int64
# history          22694 non-null object
# orig_pkts        22694 non-null int64
# orig_ip_bytes    22694 non-null int64
# resp_pkts        22694 non-null int64
# resp_ip_bytes    22694 non-null int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(8)
# memory usage: 3.3+ MB

# %% [markdown]
# ##### Data Exploration

# %%
df.describe()
# Out:
#           id.orig_p     id.resp_p     duration    orig_bytes    resp_bytes  \
# count  22694.000000  22694.000000  3870.000000  3.870000e+03  3.870000e+03
# mean   42753.924077  20598.650612     2.184969  6.310057e+05  4.165962e+03
# std    15289.541275  20788.309643    54.681427  3.042604e+07  2.107265e+05
# min        3.000000      0.000000     0.009999  0.000000e+00  0.000000e+00
# 25%    36057.750000   2133.000000     0.010000  0.000000e+00  0.000000e+00
# 50%    44316.000000  10379.000000     0.020000  0.000000e+00  0.000000e+00
# 75%    54534.500000  38230.500000     0.110000  0.000000e+00  0.000000e+00
# max    65491.000000  65535.000000  2940.989999  1.776534e+09  1.308460e+07
#
#        missed_bytes      orig_pkts  orig_ip_bytes      resp_pkts  \
# count       22694.0   22694.000000   2.269400e+04   22694.000000
# mean            0.0      11.734511   1.626597e+03      11.166476
# std             0.0    1563.859576   2.276985e+05    1558.312166
# ...

# %%
df.head()
# Out:
#                    ts                 uid        id.orig_h  id.orig_p  \
# 0 2012-03-16 18:00:00  C6SwUo2lWDfrpgfgVl   192.168.202.79      50504
# 1 2012-03-16 18:00:01  C26Bhi2scZzizn7ph9   192.168.202.79      50681
# 2 2012-03-16 18:00:50   CnbU9V2P0WWwMlO1l   192.168.202.76      51719
# 3 2012-03-16 18:01:20   Cyu9CADFj5Kg5rhf4   192.168.202.79      48479
# 4 2012-03-16 18:00:28   CcUhD5kLSPzplLI5e  192.168.202.100      45658
#
#          id.resp_h  id.resp_p proto service  duration  orig_bytes  resp_bytes  \
# 0  192.168.229.251         80   tcp    http      0.01       182.0       214.0
# 1  192.168.229.251         80   tcp    http      0.01       172.0       281.0
# 2  213.199.179.147         80   tcp       -      3.01         0.0         0.0
# 3  192.168.229.153      49160   tcp       -      0.01       198.0       118.0
# 4   192.168.27.152      17533   udp       -       NaN         NaN         NaN
#
# ...

# %%
catgorical_objects1=df.select_dtypes(include='object')
catgorical_objects1.head()
# Out:
#                   uid        id.orig_h        id.resp_h proto service  \
# 0  C6SwUo2lWDfrpgfgVl   192.168.202.79  192.168.229.251   tcp    http
# 1  C26Bhi2scZzizn7ph9   192.168.202.79  192.168.229.251   tcp    http
# 2   CnbU9V2P0WWwMlO1l   192.168.202.76  213.199.179.147   tcp       -
# 3   Cyu9CADFj5Kg5rhf4   192.168.202.79  192.168.229.153   tcp       -
# 4   CcUhD5kLSPzplLI5e  192.168.202.100   192.168.27.152   udp       -
#
#   conn_state local_orig   history
# 0         SF          -   ShADfFa
# 1         SF          -  ShADdfFa
# 2         S0          -         S
# 3         SF          -  ShADdfFa
# 4         S0          -         D

# %%
df=df.drop(['local_orig'],axis=1)

# %%
catgorical_objects1=df.select_dtypes(include='object')
catgorical_objects1.head()
# Out:
#                   uid        id.orig_h        id.resp_h proto service  \
# 0  C6SwUo2lWDfrpgfgVl   192.168.202.79  192.168.229.251   tcp    http
# 1  C26Bhi2scZzizn7ph9   192.168.202.79  192.168.229.251   tcp    http
# 2   CnbU9V2P0WWwMlO1l   192.168.202.76  213.199.179.147   tcp       -
# 3   Cyu9CADFj5Kg5rhf4   192.168.202.79  192.168.229.153   tcp       -
# 4   CcUhD5kLSPzplLI5e  192.168.202.100   192.168.27.152   udp       -
#
#   conn_state   history
# 0         SF   ShADfFa
# 1         SF  ShADdfFa
# 2         S0         S
# 3         SF  ShADdfFa
# 4         S0         D

# %%
catgorical_objects1['uid'].count()
# Out:
# 22694

# %%
catgorical_objects1['uid'].unique()
# Out:
# array(['C6SwUo2lWDfrpgfgVl', 'C26Bhi2scZzizn7ph9', 'CnbU9V2P0WWwMlO1l',
#        ..., 'CUcH0m1pw9monV3yB1', 'CLjr9N3YroTeHHAt9c',
#        'CR3R691pgm8JwRdBK8'], dtype=object)

# %%
len(catgorical_objects1['uid'].unique())
# Out:
# 22694

# %%
catgorical_objects1['proto'].count()
# Out:
# 22694

# %%
len(catgorical_objects1['proto'].unique())
# Out:
# 3

# %%
k=df.corr()
k
# Out:
#                id.orig_p  id.resp_p  duration  orig_bytes  resp_bytes  \
# id.orig_p       1.000000   0.040862 -0.002866    0.007757    0.010074
# id.resp_p       0.040862   1.000000 -0.003192   -0.021445    0.020028
# duration       -0.002866  -0.003192  1.000000    0.014564    0.863147
# orig_bytes      0.007757  -0.021445  0.014564    1.000000    0.005621
# resp_bytes      0.010074   0.020028  0.863147    0.005621    1.000000
# missed_bytes         NaN        NaN       NaN         NaN         NaN
# orig_pkts       0.005515   0.010513  0.864320    0.005525    0.998160
# orig_ip_bytes   0.005456   0.010452  0.864495    0.005501    0.998112
# resp_pkts       0.005505   0.010561  0.864231    0.005495    0.998231
# resp_ip_bytes   0.004864   0.010147  0.864190    0.005539    0.999190
#
#                missed_bytes  orig_pkts  orig_ip_bytes  resp_pkts  \
# id.orig_p               NaN   0.005515       0.005456   0.005505
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

f, ax = plt.subplots(figsize=(13, 13))

sns.heatmap(k,annot=True)

f.tight_layout()
